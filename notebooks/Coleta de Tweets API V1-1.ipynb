# %% [markdown]
# # __Tweepy: Busca de tweets com Twitter API V1.1__

# %%
import tweepy, os
import pandas as pd
import tweepy as tw

# %%
keys = {
        'consumer_key': os.environ.get('API_KEY'),
        'consumer_secret': os.environ.get('API_SECRET'),
        'access_token_key': os.environ.get('ACCESS_TOKEN'),
        'access_token_secret': os.environ.get('ACCESS_TOKEN_SECRET'),
        'bearer_token': os.environ.get('BEARER_TOKEN')
    }

# %%
# autenticação
auth = tw.OAuthHandler(keys['consumer_key'], keys['consumer_secret'])
auth.set_access_token(keys['access_token_key'], keys['access_token_secret'])
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# ## __Busca Padrão__
#
# Permite a busca de tweets em um conjunto de tweets recentes, publicados dentro de um período de 7 dias.

# %%
# método de busca, retorna uma coleção de tweets relevantes para a query de pesquisa utilizada
tweets = api.search_tweets(
    q='python', # query contendo os termos que você quer pesquisar, pode usar hashtags e até operadores lógicos
    lang='pt', # filtragem por língua
    result_type='mixed', # parâmetro utilizado para escolher os tipos de tweets retornados, mixed mistura tweets mais recentes e tweets populares
    until='2022-09-01', # retorna tweets criados antes da data escolhida
    tweet_mode='extended', # faz com que os tweets não venham truncados
    count=100 # quantidade de tweets retornados por página
)

# %% [markdown]
# Resultado da busca

# %%
len(tweets) # foram encontrados no mínimo 100 tweets contendo o termo python
# Out:
# 100

# %% [markdown]
# Conteúdo do JSON

# %%
tweets[0]._json
# Out:
# {'created_at': 'Wed Aug 31 23:57:16 +0000 2022',
#  'id': 1565126606393311232,
#  'id_str': '1565126606393311232',
#  'full_text': 'RT @lara_mesquita: Brincando com o painel "siga o dinheiro" do Jota e @basedosdados , super legal.\nE a base de dados permite acessar os dad…',
#  'truncated': False,
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'lara_mesquita',
#     'name': '🏴Lara Mesquita🗳',
#     'id': 60428407,
#     'id_str': '60428407',
#     'indices': [3, 17]},
#    {'screen_name': 'basedosdados',
#     'name': 'Base dos Dados',
#     'id': 1184334528837574656,
#     'id_str': '1184334528837574656',
#     'indices': [70, 83]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1002781992,
#   'id_str': '1002781992',
#   'name': 'Arthur Fisch',
#   'screen_name': 'atrfisch',
#   'location': 'São Paulo, Brasil',
#   'description': 'Curioso, economista e doutor em Adm Pública. Interesses: Economia, Política, Gestão Pública e #rstats. Pesquisador no @cepesp e na @confirma_site',
#   'url': 'https://t.co/x7Di3eNYo5',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/x7Di3eNYo5',
#       'expanded_url': 'https://github.com/atrfisch',
#       'display_url': 'github.com/atrfisch',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1310,
#   'friends_count': 1996,
#   'listed_count': 22,
#   'created_at': 'Mon Dec 10 23:12:07 +0000 2012',
#   'favourites_count': 14230,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 3644,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1461037006243442691/M6Y5-YDO_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1461037006243442691/M6Y5-YDO_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1002781992/1504119684',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Wed Aug 31 23:56:14 +0000 2022',
#   'id': 1565126345771843586,
#   'id_str': '1565126345771843586',
#   'full_text': 'Brincando com o painel "siga o dinheiro" do Jota e @basedosdados , super legal.\nE a base de dados permite acessar os dados em SQL no BigQuery ou com os pacotes em Python, R e Stata. Muito útil! https://t.co/mgc368jGuK',
#   'truncated': False,
#   'display_text_range': [0, 193],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'basedosdados',
#      'name': 'Base dos Dados',
#      'id': 1184334528837574656,
#      'id_str': '1184334528837574656',
#      'indices': [51, 64]}],
#    'urls': [{'url': 'https://t.co/mgc368jGuK',
#      'expanded_url': 'https://twitter.com/JotaInfo/status/1564304402306957321',
#      'display_url': 'twitter.com/JotaInfo/statu…',
#      'indices': [194, 217]}]},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 60428407,
#    'id_str': '60428407',
#    'name': '🏴Lara Mesquita🗳',
#    'screen_name': 'lara_mesquita',
#    'location': '',
#    'description': 'Political Scientist, Brazilian politics. Researcher at @fgv_clear and FGV @cepesp. Opinions are my own.\nshe/her',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5798,
#    'friends_count': 1596,
#    'listed_count': 118,
#    'created_at': 'Sun Jul 26 23:46:52 +0000 2009',
#    'favourites_count': 37057,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 37935,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'B2DFDA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1562293665707560961/5nH3PEOf_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1562293665707560961/5nH3PEOf_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/60428407/1626022113',
#    'profile_link_color': '93A644',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1564304402306957321,
#   'quoted_status_id_str': '1564304402306957321',
#   'quoted_status': {'created_at': 'Mon Aug 29 17:30:07 +0000 2022',
#    'id': 1564304402306957321,
#    'id_str': '1564304402306957321',
#    'full_text': 'Acompanhe a prestação de contas de candidatos e partidos nas eleições 2022\n\nPainel ‘Siga o Dinheiro’, em parceria com a Base dos Dados, traz transparência para o financiamento e despesas nas eleições. https://t.co/42Pff9I30l',
#    'truncated': False,
#    'display_text_range': [0, 224],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/42Pff9I30l',
#       'expanded_url': 'https://bit.ly/3ASUPuy',
#       'display_url': 'bit.ly/3ASUPuy',
#       'indices': [201, 224]}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2597576840,
#     'id_str': '2597576840',
#     'name': 'JOTA',
#     'screen_name': 'JotaInfo',
#     'location': '',
#     'description': 'Previsibilidade e transparência na política brasileira para você tomar suas decisões.',
#     'url': 'https://t.co/ygtSoBbpbt',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ygtSoBbpbt',
#         'expanded_url': 'https://www.jota.info/',
#         'display_url': 'jota.info',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 240122,
#     'friends_count': 1439,
#     'listed_count': 1705,
#     'created_at': 'Tue Jul 01 07:33:10 +0000 2014',
#     'favourites_count': 3486,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 75188,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1412150456009302020/rVn7aiGf_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1412150456009302020/rVn7aiGf_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2597576840/1610996310',
#     'profile_link_color': 'D44420',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 14,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'pt'},
#   'retweet_count': 6,
#   'favorite_count': 27,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'},
#  'is_quote_status': True,
#  'quoted_status_id': 1564304402306957321,
#  'quoted_status_id_str': '1564304402306957321',
#  'retweet_count': 6,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'pt'}

# %% [markdown]
# O limite máximo do valor do parâmetro é 100 tweets por página, entrentando, o tweepy nos permite trabalhar com paginação.
#
# Isso quer dizer que podemos buscar por uma maior quantia de tweets, distribuídos em mais de uma página contendo no máximo 100 tweets cada.

# %%
tweets_cursor = tw.Cursor(
    api.search_tweets, # o método do tweepy que será utilizado
    q='python', # query contendo os termos que você quer pesquisar, pode usar hashtags e até operadores lógicos
    lang='pt', # filtragem por língua
    result_type='mixed', # parâmetro utilizado para escolher os tipos de tweets retornados, mixed mistura tweets mais recentes e tweets populares
    until='2022-09-01', # retorna tweets criados antes da data escolhida
    tweet_mode='extended', # faz com que os tweets não venham truncados
    count=100 # quantidade de tweets retornados por página
).items(200) # você pode limitar o número de tweets que quer coletar, caso nâo queira limitar é só não setar o parâmetro em items - .items()

# %%
type(tweets_cursor)
# Out:
# tweepy.cursor.ItemIterator

# %% [markdown]
# Esse métodos retorna um cursor do tweepy, basicamente um iterator, ao invés de um JSON contendo os tweets.
#
# Para acessar os dados desse cursor é preciso iterar.

# %%
tweet_list = []

for tweet in tweets_cursor:
    tweet_list.append(tweet)
    
len(tweet_list)
# Out:
# 200

# %%
tweet_list[0]._json
# Out:
# {'created_at': 'Wed Aug 31 23:57:16 +0000 2022',
#  'id': 1565126606393311232,
#  'id_str': '1565126606393311232',
#  'full_text': 'RT @lara_mesquita: Brincando com o painel "siga o dinheiro" do Jota e @basedosdados , super legal.\nE a base de dados permite acessar os dad…',
#  'truncated': False,
#  'display_text_range': [0, 140],
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'lara_mesquita',
#     'name': '🏴Lara Mesquita🗳',
#     'id': 60428407,
#     'id_str': '60428407',
#     'indices': [3, 17]},
#    {'screen_name': 'basedosdados',
#     'name': 'Base dos Dados',
#     'id': 1184334528837574656,
#     'id_str': '1184334528837574656',
#     'indices': [70, 83]}],
#   'urls': []},
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1002781992,
#   'id_str': '1002781992',
#   'name': 'Arthur Fisch',
#   'screen_name': 'atrfisch',
#   'location': 'São Paulo, Brasil',
#   'description': 'Curioso, economista e doutor em Adm Pública. Interesses: Economia, Política, Gestão Pública e #rstats. Pesquisador no @cepesp e na @confirma_site',
#   'url': 'https://t.co/x7Di3eNYo5',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/x7Di3eNYo5',
#       'expanded_url': 'https://github.com/atrfisch',
#       'display_url': 'github.com/atrfisch',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 1310,
#   'friends_count': 1996,
#   'listed_count': 22,
#   'created_at': 'Mon Dec 10 23:12:07 +0000 2012',
#   'favourites_count': 14230,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 3644,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1461037006243442691/M6Y5-YDO_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1461037006243442691/M6Y5-YDO_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1002781992/1504119684',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': True,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Wed Aug 31 23:56:14 +0000 2022',
#   'id': 1565126345771843586,
#   'id_str': '1565126345771843586',
#   'full_text': 'Brincando com o painel "siga o dinheiro" do Jota e @basedosdados , super legal.\nE a base de dados permite acessar os dados em SQL no BigQuery ou com os pacotes em Python, R e Stata. Muito útil! https://t.co/mgc368jGuK',
#   'truncated': False,
#   'display_text_range': [0, 193],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'basedosdados',
#      'name': 'Base dos Dados',
#      'id': 1184334528837574656,
#      'id_str': '1184334528837574656',
#      'indices': [51, 64]}],
#    'urls': [{'url': 'https://t.co/mgc368jGuK',
#      'expanded_url': 'https://twitter.com/JotaInfo/status/1564304402306957321',
#      'display_url': 'twitter.com/JotaInfo/statu…',
#      'indices': [194, 217]}]},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 60428407,
#    'id_str': '60428407',
#    'name': '🏴Lara Mesquita🗳',
#    'screen_name': 'lara_mesquita',
#    'location': '',
#    'description': 'Political Scientist, Brazilian politics. Researcher at @fgv_clear and FGV @cepesp. Opinions are my own.\nshe/her',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 5798,
#    'friends_count': 1596,
#    'listed_count': 118,
#    'created_at': 'Sun Jul 26 23:46:52 +0000 2009',
#    'favourites_count': 37057,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 37935,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'B2DFDA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1562293665707560961/5nH3PEOf_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1562293665707560961/5nH3PEOf_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/60428407/1626022113',
#    'profile_link_color': '93A644',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'FFFFFF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none',
#    'withheld_in_countries': []},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1564304402306957321,
#   'quoted_status_id_str': '1564304402306957321',
#   'quoted_status': {'created_at': 'Mon Aug 29 17:30:07 +0000 2022',
#    'id': 1564304402306957321,
#    'id_str': '1564304402306957321',
#    'full_text': 'Acompanhe a prestação de contas de candidatos e partidos nas eleições 2022\n\nPainel ‘Siga o Dinheiro’, em parceria com a Base dos Dados, traz transparência para o financiamento e despesas nas eleições. https://t.co/42Pff9I30l',
#    'truncated': False,
#    'display_text_range': [0, 224],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/42Pff9I30l',
#       'expanded_url': 'https://bit.ly/3ASUPuy',
#       'display_url': 'bit.ly/3ASUPuy',
#       'indices': [201, 224]}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="https://buffer.com" rel="nofollow">Buffer</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2597576840,
#     'id_str': '2597576840',
#     'name': 'JOTA',
#     'screen_name': 'JotaInfo',
#     'location': '',
#     'description': 'Previsibilidade e transparência na política brasileira para você tomar suas decisões.',
#     'url': 'https://t.co/ygtSoBbpbt',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/ygtSoBbpbt',
#         'expanded_url': 'https://www.jota.info/',
#         'display_url': 'jota.info',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 240127,
#     'friends_count': 1439,
#     'listed_count': 1705,
#     'created_at': 'Tue Jul 01 07:33:10 +0000 2014',
#     'favourites_count': 3486,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 75188,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': True,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1412150456009302020/rVn7aiGf_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1412150456009302020/rVn7aiGf_normal.png',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2597576840/1610996310',
#     'profile_link_color': 'D44420',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none',
#     'withheld_in_countries': []},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 4,
#    'favorite_count': 14,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'pt'},
#   'retweet_count': 6,
#   'favorite_count': 27,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'},
#  'is_quote_status': True,
#  'quoted_status_id': 1564304402306957321,
#  'quoted_status_id_str': '1564304402306957321',
#  'retweet_count': 6,
#  'favorite_count': 0,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'pt'}

# %% [markdown]
# A partir desses JSON, você pode escolher as informações que quiser, criar e salvar um dataframe como csv ou parquet, ou até mesmo salvá-los como JSON.
#
# Particulamente eu prefiro utilizar compreensão de listas durante a coleta, e não costumo utilizar limite de tweets.
#
# Meus códigos costumam ficar assim:

# %%
tweets_json = [tweet._json for tweet in tw.Cursor(
    api.search_tweets,
    q='python AND "ciência de dados"',
    lang='pt',
    result_type='mixed',
    until='2022-09-01',
    tweet_mode='extended',
    count=100).items()]

print(f'Foram coletados {len(tweets_json)} tweets.')
# Out:
# Foram coletados 6 tweets.

# %%
tweets_json[0]
# Out:
# {'created_at': 'Wed Aug 31 22:47:42 +0000 2022',
#  'id': 1565109098261188608,
#  'id_str': '1565109098261188608',
#  'full_text': 'Essa disciplina de métodos números em Python vai ser show, professor já levando pra ciência de dados. Velho, a ciência brasileira é capaz de usar IA pra identificar defeitos em placa mãe de computador/notebook, isso é muito foda.',
#  'truncated': False,
#  'display_text_range': [0, 229],
#  'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#  'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1190961862139154432,
#   'id_str': '1190961862139154432',
#   'name': 'Michell Santana',
#   'screen_name': 'Deywindir',
#   'location': 'Teixeira de Freitas, Brasil',
#   'description': 'Físico pela UFES, mestrando em Modelagem Matématica e Computacional (UESC), filósofo por hobby. Meu nome é Deywindir mesmo haha!',
#   'url': None,
#   'entities': {'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 497,
#   'friends_count': 700,
#   'listed_count': 0,
#   'created_at': 'Sun Nov 03 12:00:28 +0000 2019',
#   'favourites_count': 129661,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 5064,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1475636607248224259/j_K83fFx_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1475636607248224259/j_K83fFx_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1190961862139154432/1622841835',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'has_extended_profile': False,
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none',
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'retweet_count': 0,
#  'favorite_count': 2,
#  'favorited': False,
#  'retweeted': False,
#  'lang': 'pt'}

# %% [markdown]
# ## __Busca Premium__

# %% [markdown]
# Esse diferente tipo de busca utiliza a versão premium da API do Twitter e conta com dois _end points_ distintos:
#
#   1. O _end point_ de busca de 30 dias que aumenta a janela de coleta vista na busca padrão;
#   2. O _end point_ de busca completa que nos permite coletar tweets desde 2006.
#
# Para utilizar esses tipos de buscas você precisa ter o _dev environment premium_ da API do Twitter para cada uma das duas. Eu tenho essa _feature_ por ter conseguido a versão de pesquisa acadêmica da API.

# %% [markdown]
# ## Busca de 30 dias

# %%
label = os.environ.get('SANDBOX_LABEL')

# %%
tweets_30_day = api.search_30_day(
    label='research',
    query='python',
    fromDate='202209150000', # formato timestamp
    toDate='202209200000', # formato timestamp
    maxResults=100 # valor máximo página
)

len(tweets_30_day)
# Out:
# 100

# %%
tweets_30_day = [tweet._json for tweet in tw.Cursor(
    api.search_30_day,
    label='research',
    query='python',
    fromDate='202209150000',
    toDate='202209200000',
    maxResults=100).items(200)]

len(tweets_30_day)
# Out:
# 200

# %%
tweets_30_day[0]
# Out:
# {'created_at': 'Wed Aug 31 23:59:59 +0000 2022',
#  'id': 1565127292841406465,
#  'id_str': '1565127292841406465',
#  'text': 'BrownieはPythonベースのフレームワークですか\nhttps://t.co/6RbEK7ld5f',
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1278550911829241858,
#   'id_str': '1278550911829241858',
#   'name': 'タカイ',
#   'screen_name': '1minami2',
#   'location': None,
#   'url': None,
#   'description': 'ネットワーク、ブロックチェーン、Dfinity勉強中',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 127,
#   'friends_count': 258,
#   'listed_count': 4,
#   'favourites_count': 1858,
#   'statuses_count': 750,
#   'created_at': 'Thu Jul 02 04:48:58 +0000 2020',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': '',
#   'profile_background_image_url_https': '',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1514415171997138950/eEMXHMp0_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1514415171997138950/eEMXHMp0_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1278550911829241858/1659137640',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 1,
#  'entities': {'hashtags': [],
#   'urls': [{'url': 'https://t.co/6RbEK7ld5f',
#     'expanded_url': 'https://eth-brownie.readthedocs.io/en/stable/index.html',
#     'display_url': 'eth-brownie.readthedocs.io/en/stable/inde…',
#     'indices': [29, 52]}],
#   'user_mentions': [],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'filter_level': 'low',
#  'lang': 'ja',
#  'matching_rules': [{'tag': None}]}

# %% [markdown]
# ## Busca no Arquivo
#
# Para esse tipo de busca os parâmetros são os mesmos, única diferença é que o limite do parâmetro "fromDate" vai até março de 2006 (primeiro ano do twitter).

# %%
tweets_arch = [tweet._json for tweet in tw.Cursor(
    api.search_full_archive,
    label='research',
    query='python',
    fromDate='201308150000',
    toDate='201309010000',
    maxResults=100).items(200)]

len(tweets_arch)
# Out:
# 200

# %%
tweets_arch[0]
# Out:
# {'created_at': 'Sat Aug 31 23:59:41 +0000 2013',
#  'id': 373958303325253632,
#  'id_str': '373958303325253632',
#  'text': '@RealZakWaddell   When I was dating, I enjoyed using Princess Bride, or Monte Python quotes as my test of worthyness!',
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': 373956780071464960,
#  'in_reply_to_status_id_str': '373956780071464960',
#  'in_reply_to_user_id': 1424550680,
#  'in_reply_to_user_id_str': '1424550680',
#  'in_reply_to_screen_name': 'ZakW_EDU',
#  'user': {'id': 259032188,
#   'id_str': '259032188',
#   'name': 'Sarah Reynolds',
#   'screen_name': 'Sarah_Reynolds_',
#   'location': None,
#   'url': None,
#   'description': None,
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 28,
#   'friends_count': 68,
#   'listed_count': 0,
#   'favourites_count': 37,
#   'statuses_count': 231,
#   'created_at': 'Tue Mar 01 00:56:25 +0000 2011',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/2793164197/d88086c8be51266dc1f6231c4d11325c_normal.jpeg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2793164197/d88086c8be51266dc1f6231c4d11325c_normal.jpeg',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None,
#   'withheld_in_countries': []},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 1,
#  'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'filter_level': 'low',
#  'lang': 'en',
#  'matching_rules': [{'tag': None}]}
